# %% [markdown]
# ## Facebook Sentiment Analysis using python

# %%
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
import io
import unicodedata
import numpy as np
import re
import string
from numpy import linalg
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tokenize import PunktSentenceTokenizer
from nltk.tokenize import PunktSentenceTokenizer
from nltk.corpus import webtext
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('vader_lexicon')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')


with open('kindle.txt', encoding ='ISO-8859-2') as f:
    text = f.read()
    
sent_tokenizer = PunktSentenceTokenizer(text)
sents = sent_tokenizer.tokenize(text)

print(word_tokenize(text))
print(sent_tokenize(text))

porter_stemmer = PorterStemmer()

nltk_tokens = nltk.word_tokenize(text)

for w in nltk_tokens:
    print ("Actual: % s Stem: % s" % (w, porter_stemmer.stem(w)))
    

wordnet_lemmatizer = WordNetLemmatizer()
nltk_tokens = nltk.word_tokenize(text)

for w in nltk_tokens:
    print ("Actual: % s Lemma: % s" % (w, wordnet_lemmatizer.lemmatize(w)))
    
text = nltk.word_tokenize(text)
print(nltk.pos_tag(text))

sid = SentimentIntensityAnalyzer() 
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

with open('kindle.txt', encoding ='ISO-8859-2') as f:
    for text in f.read().split('\n'):
        print(text)
        scores = sid.polarity_scores(text)
        for key in sorted(scores):
            print('{0}: {1}, '.format(key, scores[key]), end ='')
             
    print()
# Out:
# Collecting nltk
#   Using cached nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: joblib in c:\users\vivobbok 16\.conda\envs\gesturecontrol\lib\site-packages (from nltk) (1.5.3)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.1.15-cp310-cp310-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: tqdm in c:\users\vivobbok 16\.conda\envs\gesturecontrol\lib\site-packages (from nltk) (4.67.2)
# Requirement already satisfied: colorama in c:\users\vivobbok 16\.conda\envs\gesturecontrol\lib\site-packages (from click->nltk) (0.4.6)
# Using cached nltk-3.9.2-py3-none-any.whl (1.5 MB)
# Downloading regex-2026.1.15-cp310-cp310-win_amd64.whl (277 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Installing collected packages: regex, click, nltk
#
#    ---------------------------------------- 0/3 [regex]
#    ---------------------------------------- 0/3 [regex]
#    ------------- -------------------------- 1/3 [click]
#    ------------- -------------------------- 1/3 [click]
#    ------------- -------------------------- 1/3 [click]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    ---------------------------------------- 3/3 [nltk]
#
# Successfully installed click-8.3.1 nltk-3.9.2 regex-2026.1.15
# WARNING: Ignoring invalid distribution -ediapipe (c:\users\vivobbok 16\.conda\envs\gesturecontrol\lib\site-packages)
# WARNING: Ignoring invalid distribution -ediapipe (c:\users\vivobbok 16\.conda\envs\gesturecontrol\lib\site-packages)
# WARNING: Ignoring invalid distribution -ediapipe (c:\users\vivobbok 16\.conda\envs\gesturecontrol\lib\site-packages)
# [nltk_data] Downloading package vader_lexicon to C:\Users\VIVOBBOK
# [nltk_data]     16\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\VIVOBBOK
# [nltk_data]     16\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\VIVOBBOK
# [nltk_data]     16\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\VIVOBBOK 16\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\VIVOBBOK
# [nltk_data]     16\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# ['I', 'really', 'loved', 'this', 'book', '!', 'It', 'was', 'amazing', '.', 'The', 'characters', 'were', 'well', 'developed', '.', 'However', ',', 'the', 'ending', 'was', 'disappointing', '.']
# ['I really loved this book!', 'It was amazing.', 'The characters were well developed.', 'However, the ending was disappointing.']
# Actual: I Stem: i
# Actual: really Stem: realli
# Actual: loved Stem: love
# Actual: this Stem: thi
# Actual: book Stem: book
# Actual: ! Stem: !
# Actual: It Stem: it
# Actual: was Stem: wa
# Actual: amazing Stem: amaz
# Actual: . Stem: .
# Actual: The Stem: the
# Actual: characters Stem: charact
# Actual: were Stem: were
# Actual: well Stem: well
# Actual: developed Stem: develop
# Actual: . Stem: .
# Actual: However Stem: howev
# Actual: , Stem: ,
# Actual: the Stem: the
# Actual: ending Stem: end
# Actual: was Stem: wa
# Actual: disappointing Stem: disappoint
# Actual: . Stem: .
# Actual: I Lemma: I
# Actual: really Lemma: really
# Actual: loved Lemma: loved
# Actual: this Lemma: this
# Actual: book Lemma: book
# Actual: ! Lemma: !
# Actual: It Lemma: It
# Actual: was Lemma: wa
# Actual: amazing Lemma: amazing
# Actual: . Lemma: .
# Actual: The Lemma: The
# Actual: characters Lemma: character
# Actual: were Lemma: were
# Actual: well Lemma: well
# Actual: developed Lemma: developed
# Actual: . Lemma: .
# Actual: However Lemma: However
# Actual: , Lemma: ,
# Actual: the Lemma: the
# Actual: ending Lemma: ending
# Actual: was Lemma: wa
# Actual: disappointing Lemma: disappointing
# Actual: . Lemma: .
# [('I', 'PRP'), ('really', 'RB'), ('loved', 'VBD'), ('this', 'DT'), ('book', 'NN'), ('!', '.'), ('It', 'PRP'), ('was', 'VBD'), ('amazing', 'VBG'), ('.', '.'), ('The', 'DT'), ('characters', 'NNS'), ('were', 'VBD'), ('well', 'RB'), ('developed', 'VBN'), ('.', '.'), ('However', 'RB'), (',', ','), ('the', 'DT'), ('ending', 'VBG'), ('was', 'VBD'), ('disappointing', 'VBG'), ('.', '.')]
# I really loved this book! It was amazing. The characters were well developed. However, the ending was disappointing.
# compound: 0.8012, neg: 0.12, neu: 0.489, pos: 0.391,
# compound: 0.0, neg: 0.0, neu: 0.0, pos: 0.0,
